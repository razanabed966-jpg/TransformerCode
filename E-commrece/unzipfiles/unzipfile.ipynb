# %%
from google.colab import drive
drive.mount('/content/drive')

# !ls "/content/drive/MyDrive/AI/TransformerCode/E-commrece/unzipfile.ipynb"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/AI/TransformerCode/E-commrece/unzipfile.ipynb

# %%
import zipfile
import pandas as pd
import os

zip_file_path = '/content/drive/MyDrive/AI/TransformerCode/E-commrece/New WinRAR ZIP archive.zip'

working_folder=  '/content/drive/My Drive/TransformersCode/02-ECommerce/UnzipFiles'

with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(working_folder)

csv_file_path = os.path.join(working_folder, 'example.csv')
df = pd.read_csv(csv_file_path)

df.head()
# Out:
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
#                                          description
# 0  Key Features of Alisha Solid Women's Cycling S...
# 1  FabHomeDecor Fabric Double Sofa Bed (Finish Co...
# 2  Key Features of AW Bellies Sandals Wedges Heel...
# 3  Key Features of Alisha Solid Women's Cycling S...
# 4  Specifications of Sicons All Purpose Arnica Do...
